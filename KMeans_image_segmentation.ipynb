# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanmaiJami/Machine-Learning/blob/main/KMeans_image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Image segmentation using KMeans Algorithm
#04/03/2022
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
image = cv2.imread("download.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(image)
# reshape the image to a 2D array of pixels and 3 color values (RGB)
pixel_values = image.reshape((-1, 3))
print(pixel_values)
# convert to float
pixel_values = np.float32(pixel_values)
print(pixel_values)
print(pixel_values.shape)
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 0.2)
k = 3
print(criteria)
ret,labels,centers = cv2.kmeans(pixel_values, k, None, criteria, 1, cv2.KMEANS_RANDOM_CENTERS)
# convert back to 8 bit values
centers = np.uint8(centers)
print(centers)
# flatten the labels array
labels = labels.flatten()
print(labels)
# convert all pixels to the color of the centroids
segmented_image = centers[labels.flatten()]
plt.imshow(segmented_image)
# reshape back to the original image dimension
segmented_image = segmented_image.reshape(image.shape)
# show the image
plt.imshow(segmented_image)
plt.show()
# Out:
#      <input type="file" id="files-9e2576d3-8bd6-4adb-ae36-0dd6d9e3178e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e2576d3-8bd6-4adb-ae36-0dd6d9e3178e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.jpg to download (1).jpg
# [[[  6  45 100]
#   [  6  45 100]
#   [  6  45 100]
#   ...
#   [109 126 156]
#   [109 126 156]
#   [109 126 156]]
#
#  [[  7  46 101]
#   [  7  46 101]
#   [  7  46 101]
#   ...
#   [109 126 156]
#   [109 126 156]
#   [109 126 156]]
#
#  [[  6  47 101]
#   [  6  47 101]
#   [  6  47 101]
#   ...
#   [109 126 156]
#   [107 126 156]
#   [107 126 156]]
#
#  ...
#
#  [[ 55  75  26]
#   [ 34  54   5]
#   [ 49  67  17]
#   ...
#   [ 46  78  13]
#   [ 46  79  10]
#   [ 46  79  10]]
#
#  [[ 44  67  11]
#   [ 45  68  12]
# ...
