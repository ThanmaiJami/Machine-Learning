# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanmaiJami/Machine-Learning/blob/main/Scikit_learn(1_2_22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#skit-learn
#01/02/22
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
dataset = pd.read_csv('headbrain1.csv')
dataset.plot(x = 'Head Size(cm^3)', y = 'Brain Weight(grams)', style='o')
plt.title('Head Size(cm^3) Vs Brain Weight(grams)')
plt.xlabel('Head Size Studied')
plt.ylabel('Perecentage weight')
plt.show()
X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, -1].values
#Data: 80% training, 20% testing

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=0)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
#y_test = np.array(([1.8],[2.5]))
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      <input type="file" id="files-52439620-d479-42d7-b28a-41bb9add0a0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52439620-d479-42d7-b28a-41bb9add0a0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving headbrain1.csv to headbrain1.csv
#     Actual    Predicted
# 0     1280  1306.482312
# 1     1321  1294.995275
# 2     1425  1386.891571
# 3     1250  1254.268508
# 4     1350  1321.624316
# 5     1408  1286.379998
# 6     1440  1505.939045
# 7     1210  1256.618129
# 8     1422  1387.413709
# 9     1405  1339.638078
# 10    1362  1408.299231
# 11    1150  1134.959965
# 12    1175  1200.488289
# 13    1430  1335.199905
# 14    1120  1219.546328
# 15    1192  1232.077641
# 16    1163  1282.463962
# 17    1360  1356.607565
# 18    1160  1242.520402
# ...
